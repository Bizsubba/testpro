# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("✅ Libraries loaded!")
# Out:
# ✅ Libraries loaded!

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_1.csv"
df = pd.read_csv(url)
print("Shape:", df.shape)
df.head(10)
# Out:
# Shape: (90, 17)
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
# 5             6  2014-01-06       Falcon 9  3325.000000   GTO  CCAFS SLC 40
# 6             7  2014-04-18       Falcon 9  2296.000000   ISS  CCAFS SLC 40
# 7             8  2014-07-14       Falcon 9  1316.000000   LEO  CCAFS SLC 40
# 8             9  2014-08-05       Falcon 9  4535.000000   GTO  CCAFS SLC 40
# 9            10  2014-09-07       Falcon 9  4428.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# ...

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_1.csv"
df = pd.read_csv(url)
print("Shape:", df.shape)
df.head(10)
# Out:
# Shape: (90, 17)
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
# 5             6  2014-01-06       Falcon 9  3325.000000   GTO  CCAFS SLC 40
# 6             7  2014-04-18       Falcon 9  2296.000000   ISS  CCAFS SLC 40
# 7             8  2014-07-14       Falcon 9  1316.000000   LEO  CCAFS SLC 40
# 8             9  2014-08-05       Falcon 9  4535.000000   GTO  CCAFS SLC 40
# 9            10  2014-09-07       Falcon 9  4428.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# ...

# %%
# Calculate percentage of missing values
print("Missing values percentage:")
print(df.isnull().sum()/len(df)*100)
# Out:
# Missing values percentage:
# FlightNumber       0.000000
# Date               0.000000
# BoosterVersion     0.000000
# PayloadMass        0.000000
# Orbit              0.000000
# LaunchSite         0.000000
# Outcome            0.000000
# Flights            0.000000
# GridFins           0.000000
# Reused             0.000000
# Legs               0.000000
# LandingPad        28.888889
# Block              0.000000
# ReusedCount        0.000000
# Serial             0.000000
# Longitude          0.000000
# Latitude           0.000000
# dtype: float64

# %%
print("Data types:")
print(df.dtypes)
print("\nValue counts for each column:")
df.apply(pd.Series.value_counts)
# Out:
# Data types:
# FlightNumber        int64
# Date               object
# BoosterVersion     object
# PayloadMass       float64
# Orbit              object
# LaunchSite         object
# Outcome            object
# Flights             int64
# GridFins             bool
# Reused               bool
# Legs                 bool
# LandingPad         object
# Block             float64
# ReusedCount         int64
# Serial             object
# Longitude         float64
# Latitude          float64
# dtype: object
#
# Value counts for each column:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3515/354508171.py in <cell line: 0>()
#       2 print(df.dtypes)
#       3 print("\nValue counts for each column:")
# ----> 4 df.apply(pd.Series.value_counts)
#
# ...

# %%
print("Data types:")
print(df.dtypes)
# Out:
# Data types:
# FlightNumber        int64
# Date               object
# BoosterVersion     object
# PayloadMass       float64
# Orbit              object
# LaunchSite         object
# Outcome            object
# Flights             int64
# GridFins             bool
# Reused               bool
# Legs                 bool
# LandingPad         object
# Block             float64
# ReusedCount         int64
# Serial             object
# Longitude         float64
# Latitude          float64
# dtype: object

# %%
landing_outcomes = df['Outcome'].value_counts()
print("Landing Outcomes:")
print(landing_outcomes)
# Out:
# Landing Outcomes:
# Outcome
# True ASDS      41
# None None      19
# True RTLS      14
# False ASDS      6
# True Ocean      5
# False Ocean     2
# None ASDS       2
# False RTLS      1
# Name: count, dtype: int64

# %%
bad_outcomes = set(landing_outcomes.keys()[[1,3,5,6,7]])
print("Bad outcomes:")
print(bad_outcomes)
# Out:
# Bad outcomes:
# {'False ASDS', 'None None', 'False Ocean', 'None ASDS', 'False RTLS'}

# %%
landing_class = [0 if x in bad_outcomes else 1 for x in df['Outcome']]
df['Class'] = landing_class
print(df[['Outcome','Class']].head(20))
print("\nSuccess rate:", df['Class'].mean())
# Out:
#         Outcome  Class
# 0     None None      0
# 1     None None      0
# 2     None None      0
# 3   False Ocean      0
# 4     None None      0
# 5     None None      0
# 6    True Ocean      1
# 7    True Ocean      1
# 8     None None      0
# 9     None None      0
# 10  False Ocean      0
# 11   False ASDS      0
# 12   True Ocean      1
# 13   False ASDS      0
# 14    None None      0
# 15    None ASDS      0
# 16    True RTLS      1
# 17   False ASDS      0
# 18   False ASDS      0
# 19    True ASDS      1
#
# Success rate: 0.6666666666666666

# %%
df.to_csv('dataset_part_2.csv', index=False)
import shutil
shutil.copy('dataset_part_2.csv', '/content/drive/MyDrive/dataset_part_2.csv')
print("✅ Saved! Shape:", pd.read_csv('dataset_part_2.csv').shape)
df.head(5)
# Out:
# ✅ Saved! Shape: (90, 18)
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# ...

# %%
bad_outcomes = set(landing_outcomes.keys()[[1,3,5,6,7]])
print("Bad outcomes:")
print(bad_outcomes)
# Out:
# Bad outcomes:
# {'False ASDS', 'None None', 'False Ocean', 'None ASDS', 'False RTLS'}

# %%
landing_class = [0 if x in bad_outcomes else 1 for x in df['Outcome']]
df['Class'] = landing_class
print(df[['Outcome','Class']].head(20))
print("\nSuccess rate:", df['Class'].mean())
# Out:
#         Outcome  Class
# 0     None None      0
# 1     None None      0
# 2     None None      0
# 3   False Ocean      0
# 4     None None      0
# 5     None None      0
# 6    True Ocean      1
# 7    True Ocean      1
# 8     None None      0
# 9     None None      0
# 10  False Ocean      0
# 11   False ASDS      0
# 12   True Ocean      1
# 13   False ASDS      0
# 14    None None      0
# 15    None ASDS      0
# 16    True RTLS      1
# 17   False ASDS      0
# 18   False ASDS      0
# 19    True ASDS      1
#
# Success rate: 0.6666666666666666

# %%
df.to_csv('dataset_part_2.csv', index=False)
import shutil
shutil.copy('dataset_part_2.csv', '/content/drive/MyDrive/dataset_part_2.csv')
print("✅ Saved! Shape:", pd.read_csv('dataset_part_2.csv').shape)
df.head(5)
# Out:
# ✅ Saved! Shape: (90, 18)
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# ...

# %%
print("Class value counts:")
print(df['Class'].value_counts())
print("\nSuccess rate:", df['Class'].mean())
print("Total launches:", len(df))
# Out:
# Class value counts:
# Class
# 1    60
# 0    30
# Name: count, dtype: int64
#
# Success rate: 0.6666666666666666
# Total launches: 90

# %%
df.to_csv('dataset_part_2.csv', index=False)
import shutil
shutil.copy('dataset_part_2.csv', '/content/drive/MyDrive/dataset_part_2.csv')
print("✅ Saved! Shape:", pd.read_csv('dataset_part_2.csv').shape)
# Out:
# ✅ Saved! Shape: (90, 18)
