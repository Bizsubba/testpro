# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install dash plotly pandas --quiet

print("✅ Libraries installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 54.1 MB/s eta 0:00:00
# ✅ Libraries installed!

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

print("✅ Libraries loaded!")
# Out:
# ✅ Libraries loaded!

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
spacex_df = pd.read_csv(url)
print("Shape:", spacex_df.shape)
print("\nColumns:", spacex_df.columns.tolist())
print("\nLaunch Sites:")
print(spacex_df['Launch Site'].unique())
spacex_df.head()
# Out:
# Shape: (56, 7)
#
# Columns: ['Unnamed: 0', 'Flight Number', 'Launch Site', 'class', 'Payload Mass (kg)', 'Booster Version', 'Booster Version Category']
#
# Launch Sites:
# ['CCAFS LC-40' 'VAFB SLC-4E' 'KSC LC-39A' 'CCAFS SLC-40']
#    Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0           0              1  CCAFS LC-40      0                0.0
# 1           1              2  CCAFS LC-40      0                0.0
# 2           2              3  CCAFS LC-40      0              525.0
# 3           3              4  CCAFS LC-40      0              500.0
# 4           4              5  CCAFS LC-40      0              677.0
#
#   Booster Version Booster Version Category
# 0  F9 v1.0  B0003                     v1.0
# 1  F9 v1.0  B0004                     v1.0
# 2  F9 v1.0  B0005                     v1.0
# 3  F9 v1.0  B0006                     v1.0
# 4  F9 v1.0  B0007                     v1.0

# %%
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
print("Max Payload:", max_payload)
print("Min Payload:", min_payload)
# Out:
# Max Payload: 9600.0
# Min Payload: 0.0

# %%
# !pip install jupyter-dash --quiet

from jupyter_dash import JupyterDash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

# Load data
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
spacex_df = pd.read_csv(url)

max_payload = 9600.0
min_payload = 0.0

# Create app
app = JupyterDash(__name__)

# Layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dashboard',
            style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
        ],
        value='ALL',
        placeholder='Select a Launch Site here',
        searchable=True
    ),
    html.Br(),
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0,
        max=10000,
        step=1000,
        marks={0:'0', 2500:'2500', 5000:'5000', 7500:'7500', 10000:'10000'},
        value=[min_payload, max_payload]
    ),
    html.Br(),
    html.Div(dcc.Graph(id='success-payload-scatter-chart')),
])

@app.callback(
    Output('success-pie-chart', 'figure'),
    Input('site-dropdown', 'value')
)
def get_pie_chart(entered_site):
    if entered_site == 'ALL':
        fig =
# Out:
#   File "/tmp/ipykernel_1872/3087099436.py", line 58
#     fig =
#          ^
# SyntaxError: invalid syntax

# %%
dashboard_code = '''
import pandas as pd
import plotly.express as px
from jupyter_dash import JupyterDash
from dash import dcc, html
from dash.dependencies import Input, Output

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
spacex_df = pd.read_csv(url)
max_payload = spacex_df["Payload Mass (kg)"].max()
min_payload = spacex_df["Payload Mass (kg)"].min()

app = JupyterDash(__name__)

app.layout = html.Div([
    html.H1("SpaceX Launch Records Dashboard",
            style={"textAlign": "center", "color": "#503D36", "font-size": 40}),
    dcc.Dropdown(id="site-dropdown",
        options=[
            {"label": "All Sites", "value": "ALL"},
            {"label": "CCAFS LC-40", "value": "CCAFS LC-40"},
            {"label": "VAFB SLC-4E", "value": "VAFB SLC-4E"},
            {"label": "KSC LC-39A", "value": "KSC LC-39A"},
            {"label": "CCAFS SLC-40", "value": "CCAFS SLC-40"},
        ],
        value="ALL",
        placeholder="Select a Launch Site here",
        searchable=True),
    html.Br(),
    html.Div(dcc.Graph(id="success-pie-chart")),
    html.Br(),
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(id="payload-slider",
        min=0, max=10000, step=1000,
        marks={0:"0", 2500:"2500", 5000:"5000", 7500:"7500", 10000:"10000"},
        value=[min_payload, max_payload]),
    html.Br(),
    html.Div(dcc.Graph(id="success-payload-scatter-chart")),
])

@app.callback(
    Output("success-pie-chart", "figure"),
    Input("site-dropdown", "value"))
def get_pie_chart(entered_site):
    if entered_site == "ALL":
        fig = px.pie(spacex_df, values="class", names="Launch Site",
                     title="Total Successful Launches by Site")
    else:
        filtered_df = spacex_df[spacex_df["Launch Site"] == entered_site]
        filtered_df = filtered_df.groupby(["class"]).size().reset_index(name="count")
        fig = px.pie(filtered_df, values="count", names="class",
                     title=f"Success vs Failure for {entered_site}")
    return fig

@app.callback(
    Output("success-payload-scatter-chart", "figure"),
    [Input("site-dropdown", "value"),
     Input("payload-slider", "value")])
def get_scatter_chart(entered_site, payload_range):
    low, high = payload_range
    filtered_df = spacex_df[
        (spacex_df["Payload Mass (kg)"] >= low) &
        (spacex_df["Payload Mass (kg)"] <= high)]
    if entered_site == "ALL":
        fig = px.scatter(filtered_df, x="Payload Mass (kg)", y="class",
                         color="Booster Version Category",
                         title="Payload vs Launch Outcome (All Sites)")
    else:
        filtered_df = filtered_df[filtered_df["Launch Site"] == entered_site]
        fig = px.scatter(filtered_df, x="Payload Mass (kg)", y="class",
                         color="Booster Version Category",
                         title=f"Payload vs Launch Outcome for {entered_site}")
    return fig

app.run_server(mode="inline", port=8050)
'''

with open('spacex_dashboard.py', 'w') as f:
    f.write(dashboard_code)

print("✅ Dashboard file saved!")
# Out:
# ✅ Dashboard file saved!

# %%
# !pip install jupyter-dash dash plotly --quiet
print("✅ Installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 44.8 MB/s eta 0:00:00
# ✅ Installed!

# %%
import jupyter_dash
import dash
print("jupyter_dash version:", jupyter_dash.__version__)
print("dash version:", dash.__version__)
# Out:
# jupyter_dash version: 0.4.2
# dash version: 4.2.0

# %%
exec(open('spacex_dashboard.py').read())
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_dash/jupyter_app.py:103: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1872/2605298622.py in <cell line: 0>()
# ----> 1 exec(open('spacex_dashboard.py').read())
#
# <string> in <module>
#
# /usr/local/lib/python3.12/dist-packages/jupyter_dash/jupyter_app.py in run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     174         """
#     175         # Get superclass run_server method
# --> 176         super_run_server = super(JupyterDash, self).run_server
#     177
#     178         if not JupyterDash._in_ipython:
#
# AttributeError: 'super' object has no attribute 'run_server'

# %%
# !pip install dash plotly --quiet

import pandas as pd
import plotly.express as px
from dash import Dash, dcc, html
from dash.dependencies import Input, Output

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
spacex_df = pd.read_csv(url)

app = Dash(__name__)

app.layout = html.Div([
    html.H1("SpaceX Dashboard"),
    dcc.Dropdown(id="site-dropdown",
        options=[
            {"label": "All Sites", "value": "ALL"},
            {"label": "CCAFS LC-40", "value": "CCAFS LC-40"},
            {"label": "VAFB SLC-4E", "value": "VAFB SLC-4E"},
            {"label": "KSC LC-39A", "value": "KSC LC-39A"},
            {"label": "CCAFS SLC-40", "value": "CCAFS SLC-40"},
        ],
        value="ALL"),
    html.Div(dcc.Graph(id="success-pie-chart")),
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(id="payload-slider",
        min=0, max=10000, step=1000,
        marks={0:"0", 2500:"2500", 5000:"5000", 7500:"7500", 10000:"10000"},
        value=[0, 9600]),
    html.Div(dcc.Graph(id="success-payload-scatter-chart")),
])

@app.callback(
    Output("success-pie-chart", "figure"),
    Input("site-dropdown", "value"))
def get_pie_chart(entered_site):
    if entered_site == "ALL":
        fig = px.pie(spacex_df, values="class", names="Launch Site",
                     title="Total Successful Launches by Site")
    else:
        filtered_df = spacex_df[spacex_df["Launch Site"] == entered_site]
        filtered_df = filtered_df.groupby(["class"]).size().reset_index(name="count")
        fig = px.pie(filtered_df, values="count", names="class",
                     title=f"Success vs Failure for {entered_site}")
    return fig

@app.callback(
    Output("success-payload-scatter-chart", "figure"),
    [Input("site-dropdown", "value"),
     Input("payload-slider", "value")])
def get_scatter_chart(entered_site, payload_range):
    low, high = payload_range
    filtered_df = spacex_df[
        (spacex_df["Payload Mass (kg)"] >= low) &
        (spacex_df["Payload Mass (kg)"] <= high)]
    if entered_site == "ALL":
        fig = px.scatter(filtered_df, x="Payload Mass (kg)", y="class",
                         color="Booster Version Category",
                         title="Payload vs Launch Outcome (All Sites)")
    else:
        filtered_df = filtered_df[filtered_df["Launch Site"] == entered_site]
        fig = px.scatter(filtered_df, x="Payload Mass (kg)", y="class",
                         color="Booster Version Category",
                         title=f"Payload vs Launch Outcome for {entered_site}")
    return fig

app.run_server(debug=True, port=8050)
# Out:
# ---------------------------------------------------------------------------
# ObsoleteAttributeException                Traceback (most recent call last)
# /tmp/ipykernel_1872/3157390161.py in <cell line: 0>()
#      65     return fig
#      66
# ---> 67 app.run_server(debug=True, port=8050)
#
# /usr/local/lib/python3.12/dist-packages/dash/_obsolete.py in __getattr__(self, name)
#      20         if name in self._obsolete_attributes:
#      21             err = self._obsolete_attributes[name]
# ---> 22             raise err.exc(err.message)
#      23         return getattr(self.__dict__, name)
#
# ObsoleteAttributeException: app.run_server has been replaced by app.run

# %%
import pandas as pd

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
spacex_df = pd.read_csv(url)

# Success by site
print("Total Success by Site:")
print(spacex_df.groupby('Launch Site')['class'].sum())

# Success rate by site
print("\nSuccess Rate by Site:")
print(spacex_df.groupby('Launch Site')['class'].mean())

# Max/Min payload
print("\nMax Payload:", spacex_df['Payload Mass (kg)'].max())
print("Min Payload:", spacex_df['Payload Mass (kg)'].min())

# Success by Booster Version
print("\nSuccess Rate by Booster Version:")
print(spacex_df.groupby('Booster Version Category')['class'].mean())
# Out:
# Total Success by Site:
# Launch Site
# CCAFS LC-40      7
# CCAFS SLC-40     3
# KSC LC-39A      10
# VAFB SLC-4E      4
# Name: class, dtype: int64
#
# Success Rate by Site:
# Launch Site
# CCAFS LC-40     0.269231
# CCAFS SLC-40    0.428571
# KSC LC-39A      0.769231
# VAFB SLC-4E     0.400000
# Name: class, dtype: float64
#
# Max Payload: 9600.0
# Min Payload: 0.0
#
# Success Rate by Booster Version:
# Booster Version Category
# B4      0.545455
# B5      1.000000
# FT      0.666667
# v1.0    0.000000
# v1.1    0.066667
# Name: class, dtype: float64
